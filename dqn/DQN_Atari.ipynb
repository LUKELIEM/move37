# %%
# !python dqn_play.py -m ../checkpoints/PongNoFrameskip-v4-best.dat
# Out:
# ^C
# Traceback (most recent call last):
#   File "dqn_play.py", line 56, in <module>
#     time.sleep(delta)
# KeyboardInterrupt

# %%
import time

start = time.clock()  # time the training

# !python dqn_basic.py --cuda --reward 19.5

end = time.clock()
print('\nTraining time: {:.2f} min'.format((end-start)/60.0))

# %%
import time

start = time.clock()  # time the training

# !python dqn_basic.py --cuda --env "BreakoutNoFrameskip-v4"

end = time.clock()
print('\nTraining time: {:.2f} min'.format((end-start)/60.0))
# Out:
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=4, bias=True)
#   )
# )
# 137: done 1 games, mean reward 0.000, eps 1.00, speed 806.99 f/s
# 347: done 2 games, mean reward 1.000, eps 1.00, speed 765.34 f/s
# Best mean reward updated 0.000 -> 1.000, model saved
# 530: done 3 games, mean reward 1.000, eps 0.99, speed 480.38 f/s
# 691: done 4 games, mean reward 1.000, eps 0.99, speed 801.74 f/s
# 847: done 5 games, mean reward 1.000, eps 0.99, speed 658.50 f/s
# 1084: done 6 games, mean reward 1.167, eps 0.99, speed 741.73 f/s
# Best mean reward updated 1.000 -> 1.167, model saved
# ...

# %%
# !python dqn_play.py -m checkpoints/BreakoutNoFrameskip-v4-best.dat --env "BreakoutNoFrameskip-v4"
# Out:
# ^C
# Traceback (most recent call last):
#   File "dqn_play.py", line 56, in <module>
#     time.sleep(delta)
# KeyboardInterrupt

# %%
import time

start = time.clock()  # time the training

# !python dqn_basic.py --cuda --env "RobotankNoFrameskip-v4"

end = time.clock()
print('\nTraining time: {:.2f} min'.format((end-start)/60.0))

# %%
# !python dqn_play.py -m checkpoints/RobotankNoFrameskip-v4-best.dat --env "RobotankNoFrameskip-v4"
# Out:
# Total reward: 11.00
# Action counts: Counter({7: 641, 15: 271, 6: 223, 16: 168, 11: 99, 5: 90, 4: 66, 12: 59, 3: 34, 2: 24, 17: 18, 14: 18, 8: 16, 0: 6, 9: 5, 10: 1, 1: 1})

# %%
# Out:
# 100000000.0
