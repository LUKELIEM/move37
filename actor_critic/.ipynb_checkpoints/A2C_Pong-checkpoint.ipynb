# %% [markdown]
# ## Reward_Goal = 18

# %%
# !python a2c.py --cuda -n second_try
# Out:
# AtariA2C(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (policy): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
#   (value): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# 37513: done 1 games, mean reward -21.000, speed 226.32 f/s
# 37558: done 2 games, mean reward -21.000, speed 693.35 f/s
# 37661: done 3 games, mean reward -21.000, speed 178.19 f/s
# 37702: done 4 games, mean reward -21.000, speed 817.77 f/s
# 37767: done 5 games, mean reward -21.000, speed 128.21 f/s
# ...

# %% [markdown]
# ## Reward_Goal = 19.5

# %%
import time

start = time.clock()  # time the training

# !python a2c.py --cuda -n a2c_try

end = time.clock()
print('\nTraining time: {:.2f} min'.format((end-start)/60.0))
# Out:
# AtariA2C(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (policy): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
#   (value): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# 38597: done 1 games, mean reward -21.000, speed 223.52 f/s
# 39172: done 2 games, mean reward -21.000, speed 198.21 f/s
# 40517: done 3 games, mean reward -21.000, speed 243.98 f/s
# 40746: done 4 games, mean reward -21.000, speed 214.14 f/s
# 40920: done 5 games, mean reward -21.000, speed 278.79 f/s
# ...

# %%
# !pip install ptan
# !pip install tb-nightly  # Until 1.14 moves to the release channel

# %%
# !tensorboard --logdir=runs
# Out:
# Traceback (most recent call last):
#   File "/home/lukeai/miniconda3/envs/py36/bin/tensorboard", line 6, in <module>
#     from tensorboard.main import run_main
#   File "/home/lukeai/miniconda3/envs/py36/lib/python3.6/site-packages/tensorboard/main.py", line 40, in <module>
#     from tensorboard import default
#   File "/home/lukeai/miniconda3/envs/py36/lib/python3.6/site-packages/tensorboard/default.py", line 39, in <module>
#     from tensorboard.plugins.beholder import beholder_plugin_loader
#   File "/home/lukeai/miniconda3/envs/py36/lib/python3.6/site-packages/tensorboard/plugins/beholder/__init__.py", line 22, in <module>
#     from tensorboard.plugins.beholder.beholder import Beholder
#   File "/home/lukeai/miniconda3/envs/py36/lib/python3.6/site-packages/tensorboard/plugins/beholder/beholder.py", line 199, in <module>
#     class BeholderHook(tf.estimator.SessionRunHook):
# AttributeError: module 'tensorflow.python.estimator.api.estimator' has no attribute 'SessionRunHook'
