# %%
# !python a3c.py --cuda -n a3c_try
# Out:
# AtariA2C(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (policy): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
#   (value): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# 49258: done 1 games, mean reward -21.000, speed 236.58 f/s
# 49796: done 2 games, mean reward -21.000, speed 205.71 f/s
# 50479: done 3 games, mean reward -21.000, speed 264.19 f/s
# 50664: done 4 games, mean reward -21.000, speed 324.95 f/s
# 50920: done 5 games, mean reward -21.000, speed 235.85 f/s
# 50958: done 6 games, mean reward -21.000, speed 85.61 f/s
# ...
